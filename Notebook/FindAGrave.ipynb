# %%
import requests, traceback
import urllib.request
import time,re
from tqdm import tqdm
from bs4 import BeautifulSoup as beauty
import cloudscraper

urlCountry = "https://www.findagrave.com/cemetery-browse/Sweden?id=country_66"
scraper = cloudscraper.create_scraper(delay=10, browser='chrome') 

listCemeteries = []


info = scraper.get(urlCountry).text
soup = beauty(info, "html.parser")
s = soup.find_all('a')

# %%
for a in reversed(s):
    print(a)
# Out:
# <a href="/cdn-cgi/l/email-protection#82e4e7e7e6e0e3e1e9c2e4ebece6e3e5f0e3f4e7ace1edefbdf1f7e0e8e7e1f6bfd6f0e3ecf1eee3f6ebedeca7b0b2e4e7e7e6e0e3e1e9"><span class="__cf_email__" data-cfemail="80e6e5e5e4e2e1e3ebc0e6e9eee4e1e7f2e1f6e5aee3efed">[email protected]</span></a>
# <a href="https://www.ancestry.com/academy/course/adding-memorial-findagrave?embed=true&amp;playlist=findagrave-tricks-and-tips&amp;sidebar=left&amp;autoplay=true" target="_blank">View tutorials in a new tab</a>
# <a class="outlink" href="https://www.ancestry.com/cs/legal/privacystatement" target="_blank">Privacy Statement</a>
# <a class="outlink" href="https://www.ancestry.com/cs/legal/termsandconditions" target="_blank">Terms and Conditions</a>
# <a class="popover-hover" data-bs-content="A Find a Grave Photo Volunteer is a contributor who volunteers to fulfill photo requests in their area. You can alter your photo volunteer status at any time by accessing your contributor profile." data-bs-placement="top" data-bs-toggle="popover" data-bs-trigger="focus" role="button" tabindex="0" title="What is a Photo Volunteer?">What is a Photo Volunteer?</a>
# <a class="popover-hover" data-bs-content="Your Find a Grave public name defines how your name will appear to the visitors of the Find a Grave website. If you would like to remain anonymous, simply leave the field blank." data-bs-placement="bottom" data-bs-title="What is your Find a Grave Public Name?" data-bs-toggle="popover" data-bs-trigger="focus" role="button" tabindex="0">What is a Public Name?</a>
# <a class="resend-activation" data-email="#registerEmailId" href="javascript:void(0)">Resend Activation Email</a>
# <a class="initiate-registration" href="/">Sign Up</a>
# <a href="javascript:void(0)" id="signInLink">Sign in</a>
# <a href="javascript:void(0)" id="forgotPasswordLink">Forgot password?</a>
# <a class="resend-activation" href="javascript:void(0)">Resend Activation Email</a>
# <a href="/cdn-cgi/l/email-protection#30434540405f42447056595e545157425146551e535f5d0f4345525a5553440d7153535f455e44107c5f535b5554"><span class="__cf_email__" data-cfemail="661513161609141226000f08020701140710034805090b">[email protected]</span></a>
# <a href="/cdn-cgi/l/email-protection#fb888e8b8b94898fbb9d92959f9a9c899a8d9ed5989496c4888e99919e988fc6ba9898948e958fdbb79498909e9f"><span class="__cf_email__" data-cfemail="2a595f5a5a45585e6a4c43444e4b4d584b5c4f04494547">[email protected]</span></a>
# <a href="/fg-sitemap">Site Map</a>
# <a href="/community-rules">Community Rules</a>
# <a href="https://www.ancestry.com/cs/legal/privacystatement#personal-info-categories" onclick="window.open('https://www.ancestry.com/cs/legal/privacystatement#personal-info-categories' , '', 'toolbar=no,menubar=no,location=no,height=500,width=1000,resizable=yes,scrollbars=yes'); return false;"><abbr title="California Consumer Privacy Act">CCPA</abbr> Notice at Collection</a>
# <a class="ccpa_link" href="#ccpa_link" onclick="window._sp_.ccpa.loadPrivacyManagerModal('495188')" style="display: none">Do Not Sell My Information</a>
# <a class="gdpr_link" href="#gdpr_link" onclick="window._sp_.gdpr.loadPrivacyManagerModal(488737)" style="display: none">GDPR Privacy Settings</a>
# <a href="https://www.ancestry.com/cs/legal/termsandconditions" onclick="window.open('https://www.ancestry.com/cs/legal/termsandconditions' , '', 'toolbar=no,menubar=no,location=no,height=500,width=1000,resizable=yes,scrollbars=yes'); return false;">Terms of Service</a>
# <a href="https://www.ancestry.com/cs/legal/privacystatement?hideHeader=1" onclick="window.open('https://www.ancestry.com/cs/legal/privacystatement?hideHeader=1' , '', 'toolbar=no,menubar=no,location=no,height=500,width=1000,resizable=yes,scrollbars=yes'); return false;">Privacy Statement</a>
# <a href="/contact">Contact</a>
# <a class="btn btn-outline-primary btn-sm border-0 fw-bold" href="/mobileapp"><span aria-hidden="true" class="icon-mobile"></span>Mobile Apps</a>
# <a class="dropdown-item" href="javascript:changeLanguage('sv')" role="button">
#
#
#
#
#
#
#
# 	Svenska
#
# </a>
# <a class="dropdown-item" href="javascript:changeLanguage('pt')" role="button">
#
#
#
#
# 	Português
#
#
#
#
# </a>
# <a class="dropdown-item" href="javascript:changeLanguage('nl')" role="button">
#
#
#
#
#
#
#
#
# 	Nederlands
# </a>
# <a class="dropdown-item" href="javascript:changeLanguage('it')" role="button">
#
#
#
#
#
#
# 	Italiano
#
#
# </a>
# <a class="dropdown-item" href="javascript:changeLanguage('fr-ca')" role="button">
#
#
# 	Français canadien
#
#
#
#
#
#
# </a>
# <a class="dropdown-item" href="javascript:changeLanguage('fr')" role="button">
#
# 	Français
#
#
#
#
#
#
#
# </a>
# <a class="dropdown-item" href="javascript:changeLanguage('es')" role="button">
#
#
#
# 	Español
#
#
#
#
#
# </a>
# <a class="dropdown-item" href="javascript:changeLanguage('de')" role="button">
#
#
#
#
#
# 	Deutsch
#
#
#
# </a>
# <a class="dropdown-item" href="javascript:changeLanguage('en')" role="button">
# 	English
#
#
#
#
#
#
#
#
# </a>
# <a class="d-block d-md-inline my-3 my-md-0" href="/contact">Website Feedback</a>
# <a href="https://www.instagram.com/findagrave/"><span aria-hidden="true" class="icon-instagram"></span>Instagram</a>
# <a href="https://twitter.com/FindaGrave"><span aria-hidden="true" class="icon-twitter"></span>Twitter</a>
# <a href="https://www.facebook.com/FindaGrave/"><span aria-hidden="true" class="icon-facebook"></span>Facebook</a>
# <a href="/store">Store</a>
# <a href="https://www.findagraveforums.com" target="_blank">Forums</a>
# <a href="https://news.findagrave.com">News</a>
# <a href="/about">About</a>
# <a href="https://support.findagrave.com/s/" target="_blank">Help</a>
# <a href="/famous-memorial">Famous</a>
# <a href="/contribute">Contribute</a>
# <a href="/cemetery">Cemeteries</a>
# <a href="/memorial">Memorials</a>
# <a class="outlink" href="http://www.google.com/support/bin/answer.py?answer=23852" nofollow="" target="_blank">Learn how to enable it.</a>
# <a href="/cemetery-browse/Sweden/Östergötlands-län?id=state_3823">Östergötlands län</a>
# <a href="/cemetery-browse/Sweden/Örebro-län?id=state_3822">Örebro län</a>
# <a href="/cemetery-browse/Sweden/Västra-Götalands-län?id=state_3833">Västra Götalands län</a>
# <a href="/cemetery-browse/Sweden/Västmanlands-län?id=state_3830">Västmanlands län</a>
# <a href="/cemetery-browse/Sweden/Västernorrlands-län?id=state_3829">Västernorrlands län</a>
# <a href="/cemetery-browse/Sweden/Västerbottens-län?id=state_3828">Västerbottens län</a>
# <a href="/cemetery-browse/Sweden/Värmlands-län?id=state_3827">Värmlands län</a>
# <a href="/cemetery-browse/Sweden/Uppsala-län?id=state_3826">Uppsala län</a>
# <a href="/cemetery-browse/Sweden/Södermanlands-län?id=state_3825">Södermanlands län</a>
# <a href="/cemetery-browse/Sweden/Stockholms-län?id=state_3831">Stockholms län</a>
# <a href="/cemetery-browse/Sweden/Skåne-län?id=state_3832">Skåne län</a>
# <a href="/cemetery-browse/Sweden/Norrbottens-län?id=state_3821">Norrbottens län</a>
# <a href="/cemetery-browse/Sweden/Kronobergs-län?id=state_3819">Kronobergs län</a>
# <a href="/cemetery-browse/Sweden/Kalmar-län?id=state_3816">Kalmar län</a>
# <a href="/cemetery-browse/Sweden/Jönköpings-län?id=state_3815">Jönköpings län</a>
# <a href="/cemetery-browse/Sweden/Jämtlands-län?id=state_3814">Jämtlands län</a>
# <a href="/cemetery-browse/Sweden/Hallands-län?id=state_3813">Hallands län</a>
# <a href="/cemetery-browse/Sweden/Gävleborgs-län?id=state_3810">Gävleborgs län</a>
# <a href="/cemetery-browse/Sweden/Gotlands-län?id=state_3812">Gotlands län</a>
# <a href="/cemetery-browse/Sweden/Dalarnas-län?id=state_3817">Dalarnas län</a>
# <a href="/cemetery-browse/Sweden/Blekinge-län?id=state_3809">Blekinge län</a>
# <a href="/cemetery-browse?id=continent_70">Europe</a>
# <a href="/cemetery-browse">Region</a>
# <a href="/cemetery">Cemeteries</a>
# <a class="initiate-login" href="javascript:void(0)" role="button"><span class="d-none d-md-inline">Sign In</span><span aria-label="Sign In/Register" class="icon-person rounded-circle d-sm-none text-center m-0"></span></a>
# <a class="initiate-registration" href="javascript:void(0)" role="button">Register</a>
# <a class="initiate-login" href="/">Sign In</a>
# <a class="initiate-registration" href="/">Register</a>
# <a class="contributeActive" href="/contribute">Contribute</a>
# <a class="famousActive" href="/famous-memorial">Famous</a>
# <a class="cemeteryActive" href="/cemetery">Cemeteries</a>
# <a class="memorialActive" href="/memorial">Memorials</a>
# <a class="home-btn" href="/">Home</a>
# <a aria-label="Home page" href="/"><img alt="Find a Grave" height="32" src="/assets/images/logo-fff.png" width="150"/></a>
# <a class="visually-hidden-focusable position-absolute zi-popver bg-white py-1 px-3" href="#content">Skip to main content</a>

# %%
a
